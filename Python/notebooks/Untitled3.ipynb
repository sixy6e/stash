# %%
from EOtools.DatasetDrivers.stacked_dataset import StackedDataset
from EOtools.DatasetDrivers.stacked_dataset import write_band_tile
from EOtools import profiles
from EOtools import coordinates
from EOtools import pq_utils
from IDL_functions import bytscl
from IDL_functions import hist_equal
import matplotlib.cm as cm
import pandas

# %%
nir_fname = "/short/v10/jps547/DcubeDemo/coleambally/NBAR_146_-035_NIR.vrt"
red_fname = "/short/v10/jps547/DcubeDemo/coleambally/NBAR_146_-035_R.vrt"
pq_fname = "/short/v10/jps547/DcubeDemo/coleambally/PQA_146_-035_PQA.vrt"

# %%
nir_stack = StackedDataset(nir_fname)
red_stack = StackedDataset(red_fname)
pq_stack = StackedDataset(pq_fname)

# %%
nir_z = profiles.z_profile(nir_stack, (146.0210843, -34.7596891), from_map=True)

# %%
pq_z = profiles.z_profile(pq_stack, (146.0210843, -34.7596891), from_map=True)

# %%
plot(nir_z)

# %%
df = pandas.DataFrame()

# %%
df['Raw'] = nir_z.astype('float')

# %%
df[df == -999] = numpy.nan

# %%
df.plot()

# %%
flags = pq_utils.pq_apply_dict()
pq_mask = pq_utils.extract_pq_flags(pq_z.reshape(pq_z.shape[0], 1, 1), flags=flags)
# Out:
# Skipping PQ flag Empty_1
# Skipping PQ flag Empty_2

# %%
nir_masked = nir_z.astype('float')
nir_masked[~pq_mask.reshape(pq_mask.shape[0])] = -999

# %%
df['Clean'] = nir_masked
df[df == -999] = numpy.nan

# %%
df.plot()

# %%
plot(df['Raw'])

# %%
plot(df['Clean'])

# %%
nir_stack.init_yearly_iterator()

# %%
yi = nir_stack.get_yearly_iterator()

# %%
yi[1995]
# Out:
# [176,
#  177,
#  178,
#  179,
#  180,
#  181,
#  182,
#  183,
#  184,
#  185,
#  186,
#  187,
#  188,
#  189,
#  190,
#  191,
#  192,
#  193,
#  194,
#  195,
#  196,
#  197]

# %%
nir_stack.get_raster_band_datetime(930)
# Out:
# datetime.datetime(2013, 9, 23, 0, 4, 20, 944127)

# %%
dt_list = []
for i in range(1, nir_stack.bands + 1):
    dt_list.append(nir_stack.get_raster_band_datetime(i))

# %%
df['Datetime'] = dt_list

# %%
df = df.set_index('Datetime')

# %%
df['Clean'][930:1000].plot()

# %%
df[930:1000].plot()

# %%
df.plot()

# %%
from scipy import signal

# %%
smooth = signal.savgol_filter(nir_z, 5, 3)

# %%
plot(smooth[930:970])

# %%
nir_z2 = profiles.z_profile(nir_stack, (146.1436772, -34.1059362), from_map=True, raster_bands=range(1, 201))

# %%
plot(nir_z2)

# %%
df['Clean'].shape
# Out:
# (1026,)

# %%
nir_z2 = profiles.z_profile(nir_stack, (146.1436772, -34.1059362), from_map=True)

# %%
df2 = pandas.DataFrame(index=dt_list)

# %%
df2['Raw'] = nir_z2

# %%
df2['Raw'][df2['Raw'] == -999] = numpy.nan

# %%
df2[0:200].plot()

# %%
from datetime import datetime

# %%
nir_stack.get_raster_band_datetime(200)
# Out:
# datetime.datetime(1996, 2, 4, 23, 13, 22, 497019)

# %%
nir_z3 = profiles.z_profile(nir_stack, (146.1882717, -34.0172117), from_map=True)

# %%
df2['p2'] = nir_z3

# %%
df2[datetime(1988, 1, 1): datetime(1996, 2, 5)].plot()

# %%
df2[0:200].plot(title='Index by value')

# %%
plot(df2[0:200])

# %%
fig, axes = subplots(nrows=2)
df2[0:200].plot(title='Index by value', ax=axes[0])
df2[datetime(1988, 1, 1): datetime(1996, 2, 5)].plot(title='Index by date', ax=axes[1])
tight_layout()
