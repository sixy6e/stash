# %%
import numpy
numpy.random.randint(0,256,(10))
# Out:
# array([138,  76, 136,  20,  29, 127,  62,  75,  37, 197])

# %%
import pandas
ts = pandas.Series(numpy.random.randn(1000), index=pandas.date_range('1/1/2000', periods=1000))
ts = ts.cumsum()
ts.plot()
